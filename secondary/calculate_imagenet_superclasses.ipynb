# %%
from nltk.corpus import wordnet as wn
from collections import defaultdict

# %%
with open('../data/concept_sets/imagenet_label_to_wordnet_synset.txt', 'r') as f:
    class_to_id = eval(f.read())
print(class_to_id[0])

def get_all_hypernyms(synset):
    hypernyms = synset.hypernyms()
    if not hypernyms:
        return []
    else:
        all_hypernyms = []
        for hypernym in hypernyms:
            all_hypernyms.extend(get_all_hypernyms(hypernym))
            all_hypernyms.append(hypernym)
        return all_hypernyms

superclass_to_ids = defaultdict(lambda: set())

for i in range(1000):
    wn_id = class_to_id[i]['id']
    wn_number, wn_letter = wn_id.split('-')
    synset = wn.synset_from_pos_and_offset(wn_letter, int(wn_number))
    superclasses = get_all_hypernyms(synset)
    for s_synset in superclasses:
        name = s_synset.name().split('.')[0]
        name = name.replace('_', ' ')
        superclass_to_ids[name].add(i)

superclass_to_ids = dict(superclass_to_ids)
for key in superclass_to_ids:
    superclass_to_ids[key] = sorted(list(superclass_to_ids[key]))
print(len(superclass_to_ids))
# Out:
# {'id': '01440764-n', 'label': 'tench, Tinca tinca', 'uri': 'http://wordnet-rdf.princeton.edu/wn30/01440764-n'}
# 834

# %% [markdown]
# ## Delete superclasses that are identical to a final class

# %%
to_delete = []
for key in superclass_to_ids:
    if len(superclass_to_ids[key])==1:
        #print(key, superclass_to_ids[key])
        to_delete.append(key)

for key in to_delete:
    del superclass_to_ids[key]
    
print(len(superclass_to_ids))
# Out:
# 464

# %% [markdown]
# ## Delete duplicate superclasses

# %%
#prints which superclasses are identical with each other
for key in superclass_to_ids:
    for key2 in superclass_to_ids:
        if key == key2:
            continue
        elif superclass_to_ids[key] == superclass_to_ids[key2]:
            print("Identical: {}: {}".format(key, key2))
# Out:
# Identical: living thing: organism
# Identical: organism: living thing
# Identical: chordate: vertebrate
# Identical: vertebrate: chordate
# Identical: aquatic vertebrate: fish
# Identical: fish: aquatic vertebrate
# Identical: bony fish: teleost fish
# Identical: teleost fish: bony fish
# Identical: cypriniform fish: cyprinid
# Identical: cyprinid: cypriniform fish
# Identical: cartilaginous fish: elasmobranch
# Identical: elasmobranch: cartilaginous fish
# Identical: passerine: oscine
# Identical: oscine: passerine
# Identical: anapsid: chelonian
# Identical: anapsid: turtle
# Identical: chelonian: anapsid
# Identical: chelonian: turtle
# Identical: turtle: anapsid
# Identical: turtle: chelonian
# Identical: saurian: lizard
# Identical: lizard: saurian
# Identical: constrictor: boa
# Identical: boa: constrictor
# Identical: pit viper: rattlesnake
# Identical: rattlesnake: pit viper
# Identical: gallinaceous bird: game bird
# Identical: game bird: gallinaceous bird
# Identical: waterfowl: anseriform bird
# Identical: anseriform bird: waterfowl
# Identical: prototherian: monotreme
# Identical: monotreme: prototherian
# Identical: metatherian: marsupial
# Identical: marsupial: metatherian
# Identical: cetacean: whale
# Identical: whale: cetacean
# Identical: racer: greyhound
# Identical: greyhound: racer
# Identical: lamellicorn beetle: scarabaeid beetle
# Identical: scarabaeid beetle: lamellicorn beetle
# Identical: lepidopterous insect: butterfly
# Identical: butterfly: lepidopterous insect
# Identical: lagomorph: leporid
# Identical: leporid: lagomorph
# Identical: odd-toed ungulate: equine
# Identical: equine: odd-toed ungulate
# Identical: ruminant: bovid
# Identical: bovid: ruminant
# Identical: ape: anthropoid ape
# Identical: anthropoid ape: ape
# Identical: pachyderm: proboscidean
# Identical: pachyderm: elephant
# Identical: proboscidean: pachyderm
# Identical: proboscidean: elephant
# Identical: elephant: pachyderm
# Identical: elephant: proboscidean
# Identical: outerwear: gown
# Identical: gown: outerwear
# Identical: outbuilding: shed
# Identical: shed: outbuilding
# Identical: place of business: mercantile establishment
# Identical: mercantile establishment: place of business
# Identical: writing implement: pen
# Identical: pen: writing implement
# Identical: piece: piece of cloth
# Identical: piece of cloth: piece
# Identical: neckwear: necktie
# Identical: necktie: neckwear
# Identical: shield: armor plate
# Identical: armor plate: shield
# Identical: utensil: kitchen utensil
# Identical: utensil: cooking utensil
# Identical: kitchen utensil: utensil
# Identical: kitchen utensil: cooking utensil
# Identical: cooking utensil: utensil
# Identical: cooking utensil: kitchen utensil
# Identical: cutting implement: cutter
# Identical: cutting implement: edge tool
# Identical: cutter: cutting implement
# Identical: cutter: edge tool
# Identical: edge tool: cutting implement
# Identical: edge tool: cutter
# Identical: digital computer: personal computer
# Identical: personal computer: digital computer
# Identical: durables: appliance
# Identical: appliance: durables
# Identical: cosmetic: makeup
# Identical: makeup: cosmetic
# Identical: agent: drug
# Identical: drug: agent
# Identical: wagon: cart
# Identical: cart: wagon
# Identical: electrical device: transducer
# Identical: electrical device: electro-acoustic transducer
# Identical: transducer: electrical device
# Identical: transducer: electro-acoustic transducer
# Identical: electro-acoustic transducer: electrical device
# Identical: electro-acoustic transducer: transducer
# Identical: scientific instrument: magnifier
# Identical: magnifier: scientific instrument
# Identical: article: ware
# Identical: article: tableware
# Identical: ware: article
# Identical: ware: tableware
# Identical: tableware: article
# Identical: tableware: ware
# Identical: house: residence
# Identical: residence: house
# Identical: photographic equipment: camera
# Identical: camera: photographic equipment
# Identical: tank: reservoir
# Identical: reservoir: tank
# Identical: ingredient: flavorer
# Identical: ingredient: condiment
# Identical: flavorer: ingredient
# Identical: flavorer: condiment
# Identical: condiment: ingredient
# Identical: condiment: flavorer
# Identical: baked goods: bread
# Identical: bread: baked goods
# Identical: snack food: sandwich
# Identical: sandwich: snack food
# Identical: plant part: plant organ
# Identical: plant part: reproductive structure
# Identical: plant part: fruit
# Identical: plant organ: plant part
# Identical: plant organ: reproductive structure
# Identical: plant organ: fruit
# Identical: reproductive structure: plant part
# Identical: reproductive structure: plant organ
# Identical: reproductive structure: fruit
# Identical: fruit: plant part
# Identical: fruit: plant organ
# Identical: fruit: reproductive structure
# Identical: fluid: liquid
# Identical: fluid: beverage
# Identical: liquid: fluid
# Identical: liquid: beverage
# Identical: beverage: fluid
# Identical: beverage: liquid
# Identical: drug of abuse: alcohol
# Identical: alcohol: drug of abuse
# Identical: mixed drink: punch
# Identical: punch: mixed drink
# Identical: vascular plant: spermatophyte
# Identical: vascular plant: angiosperm
# Identical: vascular plant: flower
# Identical: spermatophyte: vascular plant
# Identical: spermatophyte: angiosperm
# Identical: spermatophyte: flower
# Identical: angiosperm: vascular plant
# Identical: angiosperm: spermatophyte
# Identical: angiosperm: flower
# Identical: flower: vascular plant
# Identical: flower: spermatophyte
# Identical: flower: angiosperm

# %%
#delete duplicate classes, subjectively keeping more understandable one/more descriptive of leaf classes
to_delete = ["living thing", "chordate", "aquatic vertebrate", "teleost fish", "cyprinid", "elasmobranch", "passerine", "anapsid",
             "chelonian", "saurian", "constrictor", "pit viper", "gallinaceous bird", "anseriform bird", "monotreme", "metatherian",
            "cetacean", "racer", "scarabaeid beetle", "lepidopterous insect", "lagomorph", "odd-toed ungulate", "ruminant", "anthropoid ape",
            "pachyderm", "proboscidean", "outerwear", "outbuilding", "mercantile establishment", "writing implement",
            "piece", "neckwear", "shield", "kitchen utensil", "cooking utensil", "cutting implement", "edge tool", "personal computer",
            "durables", "cosmetic", "agent", "wagon", "electrical device", "transducer", "scientific instrument", "article", "house",
            "photographic equipment", "tank", "ingredient", "flavorer", "baked goods", "snack food", "plant part", "plant organ",
             "reproductive structure", "fluid", "liquid", "drug of abuse", "punch", "vascular plant", "spermatophyte", "angiosperm", "ware"]

for key in to_delete:
    try:
        del superclass_to_ids[key]
    except(KeyError):
        print("failed to delete:{}".format(key))
print(print(len(superclass_to_ids)))

for key in superclass_to_ids:
    for key2 in superclass_to_ids:
        if key == key2:
            continue
        elif superclass_to_ids[key] == superclass_to_ids[key2]:
            print("Identical: {}, {}".format(key, key2))
# Out:
# 400
# None

# %%
import json

with open('../data/concept_sets/superclass_to_ids.json', 'w') as f:
    json.dump(superclass_to_ids, f)
